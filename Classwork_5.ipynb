# %% [markdown]
# ## Read the Dataset

# %%
# Import the pandas library
import pandas as pd 

# Read the JSON file into a pandas DataFrame, treating each line as a separate JSON object
df = pd.read_json("C:\\Users\\pbhar\\Downloads\\Arts_Crafts_and_Sewing_5.json", lines=True)

# Display a random sample of 10 rows from the DataFrame
df.sample(10)
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 187692        5      True  01 12, 2014  A3PHDOTOTV258W  B002WE3VJO
# 397724        4      True  11 10, 2017   AMAJGJKNPKD0O  B0197PWJR0
# 453128        5      True  12 18, 2017  A3DBD5M5T66273  B00874ASQM
# 72228         5      True  06 16, 2016  A1BM8X6G9M0A2L  B0013ZAJG6
# 12209         5      True   09 3, 2013  A2D2AORHOMU0CV  B0009RRTA8
# 443603        5      True  02 20, 2015  A2G6X3AZ0ALCRT  B0050L4ZDC
# 163596        5      True   12 5, 2016  A2W1F51T0F3RZZ  B001VNNKPM
# 335496        5     False   10 4, 2014  A3GOPVHU4KN0K4  B00JX10MMS
# 394260        5     False   05 2, 2016  A1ING7W0IVGKQS  B017U0OB9I
# 43920         5      True  06 22, 2016  A176JLEJK6E34L  B000WWGF2S
#
#                                                 style        reviewerName  \
# 187692                                            NaN           gmatweety
# 397724                           {'Color:': ' Black'}  God&#039;s Cowgirl
# 453128                           {'Color:': ' White'}          acceberyag
# 72228   {'Size:': ' 12"x12"', 'Color:': ' Apple Red'}         S. Vanburen
# 12209                             {'Size:': ' 25 lb'}           B. Barber
# 443603                                            NaN   Liliian Hernandez
# 163596                          {'Color:': ' Copper'}            MelissaF
# 335496                                            NaN     Lita Norsworthy
# 394260                                            NaN          MissyBissy
# 43920                       {'Color:': ' Poppyfield'}             VALERIE
#
#                                                reviewText  \
# 187692  I got this to add to my colors as I am making ...
# 397724  I haven't used these brushes yet but from the ...
# 453128                                            Perfect
# 72228   I absolutely LOVE this album! I purchased my f...
# 12209   this clay is perfect for what we ordered it fo...
# 443603                                           Love it!
# 163596                 Beautiful color and glitter detail
# 335496  So looking forward to using this great product...
# 394260  I am obsessed with finding the perfect pencils...
# 43920                                             Awesome
#
#                          summary  unixReviewTime vote  \
# 187692                a nice buy      1389484800  NaN
# 397724       GREAT PAINT BRUSHES      1510272000  NaN
# 453128                   Perfect      1513555200  NaN
# 72228           LOVE this album!      1466035200  NaN
# 12209                    perfect      1378166400  NaN
# 443603                Five Stars      1424390400  NaN
# 163596      Beautiful warm color      1480896000  NaN
# 335496                Five Stars      1412380800  NaN
# 394260  Nice pencils for drawing      1462147200    7
# 43920                 Five Stars      1466553600  NaN
#
#                                                     image
# 187692                                                NaN
# 397724                                                NaN
# 453128                                                NaN
# 72228                                                 NaN
# 12209                                                 NaN
# 443603                                                NaN
# 163596                                                NaN
# 335496                                                NaN
# 394260  [https://images-na.ssl-images-amazon.com/image...
# 43920                                                 NaN

# %% [markdown]
# ## Get the Bing Liu lexicon

# %%
import nltk

# Download the opinion lexicon 
nltk.download('opinion_lexicon')

# Import the opinion lexicon and word tokenizer
from nltk.corpus import opinion_lexicon
from nltk.tokenize import word_tokenize

# Print some information about the opinion lexicon
print('Total number of words in opinion lexicon:', len(opinion_lexicon.words()))
print('Examples of positive words in opinion lexicon:', opinion_lexicon.positive()[:10])
print('Examples of negative words in opinion lexicon:', opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon: 6789
# Examples of positive words in opinion lexicon: ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon: ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     C:\Users\pbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!

# %% [markdown]
# ## Creating the dictionary

# %%
# Let's create a dictionary which we can use for scoring our review text
nltk.download('punkt')
df.rename(columns={"reviewText": "text"}, inplace=True)
pos_score = 1
neg_score = -1
word_dict = {}
 
# Adding the positive words to the dictionary
for word in opinion_lexicon.positive():
        word_dict[word] = pos_score
      
# Adding the negative words to the dictionary
for word in opinion_lexicon.negative():
        word_dict[word] = neg_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %% [markdown]
# ## Function to do math

# %%
def bing_liu_score(text):
    sentiment_score = 0
    bag_of_words = word_tokenize(text.lower())
    for word in bag_of_words:
        if word in word_dict:
            sentiment_score += word_dict[word]
    return sentiment_score

# %% [markdown]
# ## Fill missing values

# %%
df['text'].fillna('no review', inplace=True)
df['Bing_Liu_Score'] = df['text'].apply(bing_liu_score)

# %%
df[['overall',"text", 'Bing_Liu_Score']].head(10)
# Out:
#    overall                                               text  Bing_Liu_Score
# 0        4                Contains some interesting stitches.               1
# 1        5  I'm a fairly experienced knitter of the one-co...              22
# 2        4  Great book but the index is terrible. Had to w...               0
# 3        5  I purchased the Kindle edition which is incred...               4
# 4        5  Very well laid out and very easy to read.\n\nT...               5
# 5        5  Beginning her career as a freelance knitter, M...              15
# 6        5  This is a terrific stitch handbook (and I have...               9
# 7        4  The book needs to be coil bound. The content i...               1
# 8        5  I really am enjoying this book! I like the siz...              12
# 9        5  Just received this book and looked over it cov...               6

# %% [markdown]
# ## Output

# %%
df.groupby('overall').agg({'Bing_Liu_Score':'mean'})
# Out:
#          Bing_Liu_Score
# overall
# 1             -0.255049
# 2              0.566098
# 3              1.158796
# 4              2.028146
# 5              2.130005
