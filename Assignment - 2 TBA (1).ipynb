# %% [markdown]
# ## Reading the CSV File and Displaying the DataFrame!

# %%
# importing pandas library
import pandas as pd

# Giving the path of the CSV file and stored in a variable name file
file = "C:\\Users\\pbhar\\Downloads\\incidenceukus new.csv"

# Reading the CSV file and stored in a variable named called dataframe(df)
df = pd.read_csv(file)

# Printing the first 20 rows of the data from the CSV file
df.head(20)
# Out:
#            Country Code  Year  Child Labor in Urban Britain  \
# 0   United Kingdom  GBR  1851                          19.9
# 1   United Kingdom  GBR  1861                          20.2
# 2   United Kingdom  GBR  1871                          20.5
# 3   United Kingdom  GBR  1881                          15.1
# 4   United Kingdom  GBR  1891                          16.3
# 5   United Kingdom  GBR  1901                          12.0
# 6   United Kingdom  GBR  1911                          10.4
# 7                0    0     0                           0.0
# 8                0    0     0                           0.0
# 9                0    0     0                           0.0
# 10               0    0     0                           0.0
# 11               0    0     0                           0.0
# 12               0    0     0                           0.0
# 13               0    0     0                           0.0
# 14               0    0     0                           0.0
# 15               0    0     0                           0.0
# 16               0    0     0                           0.0
# 17               0    0     0                           0.0
# 18               0    0     0                           0.0
# 19               0    0     0                           0.0
#
#     Child Labor UK boys, historic                   Entity  Year.1  \
# 0                            36.6               Both sexes    1890
# 1                            36.9               Both sexes    1900
# 2                            32.1               Both sexes    1910
# 3                            22.9               Both sexes    1920
# 4                            26.0               Both sexes    1930
# 5                            21.9  Both sexes, rural areas    1890
# 6                            18.3  Both sexes, rural areas    1900
# 7                             0.0  Both sexes, rural areas    1910
# 8                             0.0  Both sexes, rural areas    1920
# 9                             0.0  Both sexes, rural areas    1930
# 10                            0.0  Both sexes, urban areas    1890
# 11                            0.0  Both sexes, urban areas    1900
# 12                            0.0  Both sexes, urban areas    1910
# 13                            0.0  Both sexes, urban areas    1920
# 14                            0.0  Both sexes, urban areas    1930
# 15                            0.0                     Boys    1890
# 16                            0.0                     Boys    1900
# 17                            0.0                     Boys    1910
# 18                            0.0                     Boys    1920
# 19                            0.0                     Boys    1930
#
#    Child Labor Long 1958
# 0          1.165.964.912
# 1          1.202.615.385
# 2          6.555.555.556
# 3          4.365.116.279
# 4          2.462.886.598
# 5          1.327.948.718
# 6          1.344.651.163
# 7                    9.2
# 8                   6.95
# 9          4.532.653.061
# 10                  8.15
# 11                  9.25
# 12                   2.4
# 13                   1.1
# 14                  0.35
# 15         1.771.034.483
# 16         1.776.666.667
# 17         9.172.222.222
# 18         5.874.418.605
# 19         3.357.142.857

# %% [markdown]
# ## Columns

# %%
# Prinitng the column names for an overview
df.columns
# Out:
# Index(['Country', 'Code', 'Year', 'Child Labor in Urban Britain',
#        'Child Labor UK boys, historic', 'Entity', 'Year.1',
#        'Child Labor Long 1958'],
#       dtype='object')

# %% [markdown]
# ## dtypes

# %%
# Printing the data types of the columns
df.dtypes
# Out:
# Country                           object
# Code                              object
# Year                               int64
# Child Labor in Urban Britain     float64
# Child Labor UK boys, historic    float64
# Entity                            object
# Year.1                             int64
# Child Labor Long 1958             object
# dtype: object

# %% [markdown]
# ## info()

# %%
# Printing the information for an overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        45 non-null     object
#  1   Code                           45 non-null     object
#  2   Year                           45 non-null     int64
#  3   Child Labor in Urban Britain   45 non-null     float64
#  4   Child Labor UK boys, historic  45 non-null     float64
#  5   Entity                         45 non-null     object
#  6   Year.1                         45 non-null     int64
#  7   Child Labor Long 1958          45 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.9+ KB

# %% [markdown]
# ## describe()

# %%
# Describing the data of the CSV File
df.describe()
# Out:
#              Year  Child Labor in Urban Britain  \
# count    45.00000                     45.000000
# mean    292.60000                      2.542222
# std     689.48701                      6.177911
# min       0.00000                      0.000000
# 25%       0.00000                      0.000000
# 50%       0.00000                      0.000000
# 75%       0.00000                      0.000000
# max    1911.00000                     20.500000
#
#        Child Labor UK boys, historic       Year.1
# count                      45.000000    45.000000
# mean                        4.326667  1910.000000
# std                        10.557298    14.301939
# min                         0.000000  1890.000000
# 25%                         0.000000  1900.000000
# 50%                         0.000000  1910.000000
# 75%                         0.000000  1920.000000
# max                        36.900000  1930.000000

# %% [markdown]
# ## New column with the Length of the "Entity" Column

# %%
# Adding a new column with the length of the “Entity” column
df['length'] = df['Entity'].str.len()

# Describing the output
df.describe()
# Out:
#              Year  Child Labor in Urban Britain  \
# count    45.00000                     45.000000
# mean    292.60000                      2.542222
# std     689.48701                      6.177911
# min       0.00000                      0.000000
# 25%       0.00000                      0.000000
# 50%       0.00000                      0.000000
# 75%       0.00000                      0.000000
# max    1911.00000                     20.500000
#
#        Child Labor UK boys, historic       Year.1     length
# count                      45.000000    45.000000  45.000000
# mean                        4.326667  1910.000000  15.000000
# std                        10.557298    14.301939   6.741999
# min                         0.000000  1890.000000   4.000000
# 25%                         0.000000  1900.000000  10.000000
# 50%                         0.000000  1910.000000  17.000000
# 75%                         0.000000  1920.000000  18.000000
# max                        36.900000  1930.000000  23.000000

# %% [markdown]
# ## Text Field

# %%
# Using the Describe method
df.describe(include='O')
# Out:
#        Country Code      Entity Child Labor Long 1958
# count       45   45          45                    45
# unique       2    2           9                    43
# top          0    0  Both sexes                   6.1
# freq        38   38           5                     2

# %% [markdown]
# ## Check for Missing Data

# %%
# Checking for missing data
df.isna().sum()
# Out:
# Country                          0
# Code                             0
# Year                             0
# Child Labor in Urban Britain     0
# Child Labor UK boys, historic    0
# Entity                           0
# Year.1                           0
# Child Labor Long 1958            0
# length                           0
# dtype: int64

# %% [markdown]
# ## Uppercase (or Lowercase) 'Country' Column

# %%
# Converting and printing the 'Country' column data into uppercase using upper() method
df['Country'] = df['Country'].str.upper()
df
# Out:
#            Country Code  Year  Child Labor in Urban Britain  \
# 0   UNITED KINGDOM  GBR  1851                          19.9
# 1   UNITED KINGDOM  GBR  1861                          20.2
# 2   UNITED KINGDOM  GBR  1871                          20.5
# 3   UNITED KINGDOM  GBR  1881                          15.1
# 4   UNITED KINGDOM  GBR  1891                          16.3
# 5   UNITED KINGDOM  GBR  1901                          12.0
# 6   UNITED KINGDOM  GBR  1911                          10.4
# 7                0    0     0                           0.0
# 8                0    0     0                           0.0
# 9                0    0     0                           0.0
# 10               0    0     0                           0.0
# 11               0    0     0                           0.0
# 12               0    0     0                           0.0
# 13               0    0     0                           0.0
# 14               0    0     0                           0.0
# 15               0    0     0                           0.0
# 16               0    0     0                           0.0
# 17               0    0     0                           0.0
# 18                            0.0                     Boys    1920
# 19                            0.0                     Boys    1930
# 20                            0.0        Boys, rural areas    1890
# 21                            0.0        Boys, rural areas    1900
# 22                            0.0        Boys, rural areas    1910
# 23                            0.0        Boys, rural areas    1920
# 24                            0.0        Boys, rural areas    1930
# 25                            0.0        Boys, urban areas    1890
# 26                            0.0        Boys, urban areas    1900
# 27                            0.0        Boys, urban areas    1910
# 28                            0.0        Boys, urban areas    1920
# 29                            0.0        Boys, urban areas    1930
# 30                            0.0                    Girls    1890
# 31                            0.0                    Girls    1900
# 32                            0.0                    Girls    1910
# 33                            0.0                    Girls    1920
# 34                            0.0                    Girls    1930
# 35                            0.0       Girls, rural areas    1890
# 36                            0.0       Girls, rural areas    1900
# 37                            0.0       Girls, rural areas    1910
# 38                            0.0       Girls, rural areas    1920
# 39                            0.0       Girls, rural areas    1930
# 40                            0.0       Girls, urban areas    1890
# 41                            0.0       Girls, urban areas    1900
# 42                            0.0       Girls, urban areas    1910
# 43                            0.0       Girls, urban areas    1920
# 44                            0.0       Girls, urban areas    1930
#
#    Child Labor Long 1958  length
# 0          1.165.964.912      10
# 1          1.202.615.385      10
# 2          6.555.555.556      10
# 3          4.365.116.279      10
# 4          2.462.886.598      10
# 5          1.327.948.718      23
# 6          1.344.651.163      23
# 7                    9.2      23
# 8                   6.95      23
# 9          4.532.653.061      23
# 10                  8.15      23
# 11                  9.25      23
# 12                   2.4      23
# 13                   1.1      23
# 14                  0.35      23
# 15         1.771.034.483       4
# 16         1.776.666.667       4
# 17         9.172.222.222       4
# 18         5.874.418.605       4
# 19         3.357.142.857       4
# 20                  20.1      17
# 21                  19.6      17
# 22                  13.1      17
# 23                   9.1      17
# 24                   6.1      17
# 25                  12.4      17
# 26                  14.1      17
# 27                     3      17
# 28                   1.8      17
# 29                   0.5      17
# 30         5.392.857.143       5
# 31               610.625       5
# 32         3.938.888.889       5
# 33         2.855.813.953       5
# 34                  1.55       5
# 35                   6.1      18
# 36                     7      18
# 37                   5.3      18
# 38                   4.8      18
# 39                   2.9      18
# 40                   3.9      18
# 41                   4.4      18
# 42                   1.8      18
# 43                   0.4      18
# 44                   0.2      18

# %% [markdown]
# ## Uppercase (or Lowercase) 'Entity' Column

# %%
# Converting and printing the 'Entity' column data into uppercase using upper() method
df['Entity'] = df['Entity'].str.upper()
df
# Out:
#            Country Code  Year  Child Labor in Urban Britain  \
# 0   UNITED KINGDOM  GBR  1851                          19.9
# 1   UNITED KINGDOM  GBR  1861                          20.2
# 2   UNITED KINGDOM  GBR  1871                          20.5
# 3   UNITED KINGDOM  GBR  1881                          15.1
# 4   UNITED KINGDOM  GBR  1891                          16.3
# 5   UNITED KINGDOM  GBR  1901                          12.0
# 6   UNITED KINGDOM  GBR  1911                          10.4
# 7                0    0     0                           0.0
# 8                0    0     0                           0.0
# 9                0    0     0                           0.0
# 10               0    0     0                           0.0
# 11               0    0     0                           0.0
# 12               0    0     0                           0.0
# 13               0    0     0                           0.0
# 14               0    0     0                           0.0
# 15               0    0     0                           0.0
# 16               0    0     0                           0.0
# 17               0    0     0                           0.0
# 18               0    0     0                           0.0
# 19               0    0     0                           0.0
# 3          4.365.116.279      10
# 4          2.462.886.598      10
# 5          1.327.948.718      23
# 6          1.344.651.163      23
# 7                    9.2      23
# 8                   6.95      23
# 9          4.532.653.061      23
# 10                  8.15      23
# 11                  9.25      23
# 12                   2.4      23
# 13                   1.1      23
# 14                  0.35      23
# 15         1.771.034.483       4
# 16         1.776.666.667       4
# 17         9.172.222.222       4
# 18         5.874.418.605       4
# 19         3.357.142.857       4
# 20                  20.1      17
# 21                  19.6      17
# 22                  13.1      17
# 23                   9.1      17
# 24                   6.1      17
# 25                  12.4      17
# 26                  14.1      17
# 27                     3      17
# 28                   1.8      17
# 29                   0.5      17
# 30         5.392.857.143       5
# 31               610.625       5
# 32         3.938.888.889       5
# 33         2.855.813.953       5
# 34                  1.55       5
# 35                   6.1      18
# 36                     7      18
# 37                   5.3      18
# 38                   4.8      18
# 39                   2.9      18
# 40                   3.9      18
# 41                   4.4      18
# 42                   1.8      18
# 43                   0.4      18
# 44                   0.2      18

# %% [markdown]
# ## Country with 'UNITED KINGDOM' in them

# %%
# Printing the data contains 'UNITED KINGDOM' in Country column
df[df['Country'].str.contains('UNITED KINGDOM')]
# Out:
#           Country Code  Year  Child Labor in Urban Britain  \
# 0  UNITED KINGDOM  GBR  1851                          19.9
# 1  UNITED KINGDOM  GBR  1861                          20.2
# 2  UNITED KINGDOM  GBR  1871                          20.5
# 3  UNITED KINGDOM  GBR  1881                          15.1
# 4  UNITED KINGDOM  GBR  1891                          16.3
# 5  UNITED KINGDOM  GBR  1901                          12.0
# 6  UNITED KINGDOM  GBR  1911                          10.4
#
#    Child Labor UK boys, historic                   Entity  Year.1  \
# 0                           36.6               BOTH SEXES    1890
# 1                           36.9               BOTH SEXES    1900
# 2                           32.1               BOTH SEXES    1910
# 3                           22.9               BOTH SEXES    1920
# 4                           26.0               BOTH SEXES    1930
# 5                           21.9  BOTH SEXES, RURAL AREAS    1890
# 6                           18.3  BOTH SEXES, RURAL AREAS    1900
#
#   Child Labor Long 1958  length
# 0         1.165.964.912      10
# 1         1.202.615.385      10
# 2         6.555.555.556      10
# 3         4.365.116.279      10
# 4         2.462.886.598      10
# 5         1.327.948.718      23
# 6         1.344.651.163      23

# %% [markdown]
# ## Charts

# %%
# Plotting the Graph
df['length'].plot()
# Out:
# <Axes: >

# %%
# Plotting the length graph in a kind of box in the horizontal position 
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Histogram

# %%
# Plotting the histogram Graph labelling Y-axis as Frequency
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Bar Plot

# %%
# Printing the Bar Plot taking X-axis as 'Code' and Y-axis as 'Length'
import seaborn as sns
where = df['Code'].isin(['GBR', '0'])
g = sns.catplot(data=df[where], x="Code", y="length", kind='box')
g.fig.set_size_inches(10, 8) ###

# %% [markdown]
# ## Function to tokenize

# %%
# Tokenizing a Function using a function tokenize()
import regex as re
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

x = tokenize('Bhargavi Prodduturi')
print(x)
# Out:
# ['Bhargavi', 'Prodduturi']

# %% [markdown]
# ## Example

# %%
# Try it out before running it on the whole dataset
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ## Remove Stopwords

# %%
# We will use the list of English stop words that are standard in python
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'you', 'do', 'further', 'more', 'll', 'ain', 'if', 'such', 'very', 'itself', 'who', 'own', 'were', 'is', 'then', "doesn't", 'below', 'my', 'again', 'are', 'a', 'under', 'same', 'can', "should've", 'couldn', "hasn't", 'been', 'against', 'before', 'this', 'why', 'with', "shan't", 'd', 'all', 'themselves', "needn't", 'into', 'being', 'was', 'her', 'each', 'how', "that'll", 't', 'now', 'me', 's', "it's", 'shouldn', 'off', 'wouldn', "mightn't", 'in', "you'll", 'on', "weren't", 'above', 'to', 'up', 'theirs', 'no', 'so', "wasn't", 'has', "mustn't", 'ours', 'those', 'the', 'be', 'him', 'their', "you've", 'having', 'hadn', 'it', 'an', 'himself', 'about', 'not', 'should', "you're", 'out', 're', 'she', 'there', 'down', 'does', 'than', 'will', 'during', "won't", "she's", 'only', 'of', 'few', 'won', 'too', 'his', 'by', 'over', 'because', 'just', 'shan', 'for', 'doesn', 'yourself', 'had', 'm', 'where', 'weren', 'what', 'which', 'y', 'whom', 'as', "isn't", 'herself', 'between', 'when', 'don', "hadn't", 'aren', 'mustn', 'after', 'most', 'these', 'hers', 'am', 'while', 'both', 'he', 'ourselves', 'nor', 've', 'they', 'doing', 'your', 'any', "aren't", "don't", 'its', 'mightn', 'from', 'didn', 'we', 'some', 'hasn', 'them', 'at', "haven't", 'yours', "didn't", 'and', 'but', 'myself', 'have', 'once', 'here', "wouldn't", "you'd", 'until', 'or', 'isn', "shouldn't", 'yourselves', 'did', 'ma', "couldn't", 'i', 'haven', 'through', 'o', 'other', 'that', 'needn', 'our', 'wasn'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Function to remove stopwords

# %%
# Removing the stop words using a function remove_stop()
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# ## Let's make a Pipeline

# %%
# Making a Pipeline
pipeline = [str.lower, tokenize, remove_stop]
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ## Run the Pipeline

# %%
# Running a pipeline
df['tokens'] = df['Entity'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ## Count the tokens

# %%
# Counting the number of tokens using length method
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#    Country Code  Year  Child Labor in Urban Britain  \
# 40       0    0     0                           0.0
# 41       0    0     0                           0.0
# 42       0    0     0                           0.0
# 43       0    0     0                           0.0
# 44       0    0     0                           0.0
#
#     Child Labor UK boys, historic              Entity  Year.1  \
# 40                            0.0  GIRLS, URBAN AREAS    1890
# 41                            0.0  GIRLS, URBAN AREAS    1900
# 42                            0.0  GIRLS, URBAN AREAS    1910
# 43                            0.0  GIRLS, URBAN AREAS    1920
# 44                            0.0  GIRLS, URBAN AREAS    1930
#
#    Child Labor Long 1958  length                 tokens  num_tokens
# 40                   3.9      18  [girls, urban, areas]           3
# 41                   4.4      18  [girls, urban, areas]           3
# 42                   1.8      18  [girls, urban, areas]           3
# 43                   0.4      18  [girls, urban, areas]           3
# 44                   0.2      18  [girls, urban, areas]           3

# %% [markdown]
# ## Use the Counter

# %%
# Using the Counter method
from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# ## Add new data to the current count

# %%
# Adding the new data to the current count
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ## Let's Count

# %%
# Counting the most common 5 tokens using map() method
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('areas', 30), ('sexes', 15), ('rural', 15), ('urban', 15), ('boys', 15)]

# %% [markdown]
# ## put the word frequency in it's own dataframe for analysis

# %%
# put the word frequency in it’s own dataframe for analysis
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# ## Sort and Display!

# %%
# Sorting and Displaying 10 values of the frequency dataframe
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#        freq
# token
# areas    30
# sexes    15
# rural    15
# urban    15
# boys     15
# girls    15

# %% [markdown]
# ## Stats!

# %%
# Describing the data of the frequency dataframe
freq_df.describe()
# Out:
#             freq
# count   6.000000
# mean   17.500000
# std     6.123724
# min    15.000000
# 25%    15.000000
# 50%    15.000000
# 75%    15.000000
# max    30.000000

# %% [markdown]
# ## Bar chart

# %%
# plotting top 15 frequency dataframe names in the Y-axis named Token
ax = freq_df.head(15).plot(kind='barh', width=0.50, figsize=(12,8))
ax.invert_yaxis()

# Taking X-axis as 'Frequency', Y-axis as 'Token' and title as 'Top Words'
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ## Pip Installation

# %%
# Installing wordcloud
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\pbhar\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\pbhar\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\pbhar\anaconda3\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\pbhar\anaconda3\lib\site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pbhar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pbhar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pbhar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pbhar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pbhar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pbhar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pbhar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pbhar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# ## Word Cloud

# %%
# Importing libraries wordcloud and matplotlib
from wordcloud import WordCloud
from matplotlib import pyplot as plt

# Printing output with the needy requirements
text = df.query("Year==1851 and Country == 'UNITED KINGDOM'")['Country'].values[0]
plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## All Data Word Cloud

# %%
# Printing output with the needy requirements
wc = WordCloud(background_color='white', width = 300, height=300,max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
